# %%
import numpy as np
import matplotlib.pyplot as plt
import math  

data = './data/'

P_path = data+'P.txt'
Q_path = data+'Q_obs.txt'
Temp_path = data+'temperature.txt'
kc_path = data+'kc.txt' #crop coefficient

P = np.load(P_path)
